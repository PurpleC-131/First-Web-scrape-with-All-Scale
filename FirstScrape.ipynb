# %%
import requests
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/Japan'
response = requests.get(url)
soup = BeautifulSoup(response.content,'html.parser')

# %%
body = soup.find('body').text

# %%
first_link = soup.find('figure', class_ = 'mw-default-size')
link = first_link.find('img',src=True)
link['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/6/6b/Emperor_Jimmu.jpg/170px-Emperor_Jimmu.jpg'

# %%
all_picture_links = soup.find_all('figure', class_ = 'mw-default-size')
for i in all_picture_links:
    link = i.find('img',src=True)
    print(link['src'])
# Out:
# //upload.wikimedia.org/wikipedia/commons/thumb/6/6b/Emperor_Jimmu.jpg/170px-Emperor_Jimmu.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Mokoshuraiekotoba.jpg/220px-Mokoshuraiekotoba.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/7/79/The_Three_Unifiers_of_Japan.jpg/220px-The_Three_Unifiers_of_Japan.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/9/94/Mamoru_Shigemitsu_signs_the_Instrument_of_Surrender%2C_officially_ending_the_Second_World_War.jpg/220px-Mamoru_Shigemitsu_signs_the_Instrument_of_Surrender%2C_officially_ending_the_Second_World_War.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/0/01/Japan_topo_en.jpg/260px-Japan_topo_en.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/6/66/Chuurei-tou_Fujiyoshida_17025277650_c59733d6ba_o.jpg/220px-Chuurei-tou_Fujiyoshida_17025277650_c59733d6ba_o.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Kongobuji_Koyasan07n3200.jpg/220px-Kongobuji_Koyasan07n3200.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Emperor_Naruhito_and_Empress_Masako_cropped_Emperor_Naruhito_and_Empress_Masako_20191110_1.jpg/220px-Emperor_Naruhito_and_Empress_Masako_cropped_Emperor_Naruhito_and_Empress_Masako_20191110_1.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/1/12/Diet_of_Japan_Kokkai_2009.jpg/220px-Diet_of_Japan_Kokkai_2009.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Regions_and_Prefectures_of_Japan_2.svg/290px-Regions_and_Prefectures_of_Japan_2.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/1/1e/G7_in_het_Catshuis.jpg/260px-G7_in_het_Catshuis.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d1/US_Navy_051115-N-8492C-125_The_Japan_Maritime_Self-Defense_Force_%28JMSDF%29_destroyer_JDS_Kongou_%28DDG_173%29_sails_in_formation_with_other_JMSDF_ships_and_ships_assigned_to_the_USS_Kitty_Hawk_Carrier_Strike_Group.jpg/220px-thumbnail.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/f/f8/%E8%AD%A6%E8%A6%96%E5%BA%81_-_panoramio.jpg/220px-%E8%AD%A6%E8%A6%96%E5%BA%81_-_panoramio.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/7/71/Nakanoshima_Skyscrapers_in_201504_001.jpg/220px-Nakanoshima_Skyscrapers_in_201504_001.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/e/e9/Rice_Paddies_In_Aizu%2C_Japan.JPG/220px-Rice_Paddies_In_Aizu%2C_Japan.JPG
# //upload.wikimedia.org/wikipedia/commons/thumb/7/7c/2018_Nissan_GT-R_Premium_in_Super_Silver%2C_Front_Right%2C_10-11-2022.jpg/290px-2018_Nissan_GT-R_Premium_in_Super_Silver%2C_Front_Right%2C_10-11-2022.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Kibo_PM_and_ELM-PS.jpg/220px-Kibo_PM_and_ELM-PS.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Japan_Airlines%2C_Boeing_787-9_JA861J_NRT_%2819455285040%29.jpg/220px-Japan_Airlines%2C_Boeing_787-9_JA861J_NRT_%2819455285040%29.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Setokazenooka-park01.jpg/220px-Setokazenooka-park01.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/4/4e/Tokyo_from_the_top_of_the_SkyTree.JPG/260px-Tokyo_from_the_top_of_the_SkyTree.JPG
# //upload.wikimedia.org/wikipedia/commons/thumb/b/b9/%E8%B1%9A%E9%AA%A8%E3%82%89%E3%83%BC%E3%82%81%E3%82%93_%E5%8D%9A%E5%A4%9A%E5%A4%A9%E7%A5%9E_%E3%81%84%E3%82%89%E3%81%A3%E3%81%97%E3%82%83%E3%81%84_2010_%285023366778%29.jpg/220px-%E8%B1%9A%E9%AA%A8%E3%82%89%E3%83%BC%E3%82%81%E3%82%93_%E5%8D%9A%E5%A4%9A%E5%A4%A9%E7%A5%9E_%E3%81%84%E3%82%89%E3%81%A3%E3%81%97%E3%82%83%E3%81%84_2010_%285023366778%29.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Itsukushima_Shrine_Torii_Gate_%2813890465459%29.jpg/220px-Itsukushima_Shrine_Torii_Gate_%2813890465459%29.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/5/57/Tokyo_University_Entrance_Exam_Results_6.JPG/220px-Tokyo_University_Entrance_Exam_Results_6.JPG
# //upload.wikimedia.org/wikipedia/commons/thumb/0/01/University_of_Tokyo_Hospital.JPG/260px-University_of_Tokyo_Hospital.JPG
# //upload.wikimedia.org/wikipedia/commons/thumb/6/69/Genji_emaki_01003_001.jpg/220px-Genji_emaki_01003_001.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/b/bf/%E6%98%A5%E6%97%A5%E7%A5%9E%E7%A4%BE%E3%83%BC%E7%AF%A0%E5%B1%B1%E3%83%BC%E7%BF%81%E5%A5%89%E7%B4%8DP1011774.jpg/220px-%E6%98%A5%E6%97%A5%E7%A5%9E%E7%A4%BE%E3%83%BC%E7%AF%A0%E5%B1%B1%E3%83%BC%E7%BF%81%E5%A5%89%E7%B4%8DP1011774.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/2/22/Young_ladies_at_Harajuku.jpg/220px-Young_ladies_at_Harajuku.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/9/94/East_West_sushi_01.jpg/220px-East_West_sushi_01.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/e/eb/Aki_basho_dohy%C5%8D-iri_on_Sept._28_2014.jpg/220px-Aki_basho_dohy%C5%8D-iri_on_Sept._28_2014.jpg

# %%
toc = soup.find('ul',class_ = "vector-toc-contents")
headings = toc.find_all('div', class_ = "vector-toc-text")
for heading in headings:
    print (heading.text)
# Out:
# (Top)
#
# 1
# Etymology
#
#
# 2
# History
#
#
# 2.1
# Prehistoric to classical history
#
#
# 2.2
# Feudal era
#
#
# 2.3
# Modern era
#
#
# 3
# Geography
#
#
# 3.1
# Climate
#
#
# 3.2
# Biodiversity
#
#
# 3.3
# Environment
#
#
# 4
# Government and politics
#
#
# 4.1
# Administrative divisions
#
#
# 4.2
# Foreign relations
#
#
# 4.3
# Military
#
#
# 4.4
# Law enforcement
#
#
# 4.5
# Human rights
#
#
# 5
# Economy
#
#
# 5.1
# Agriculture and fishery
#
#
# 5.2
# Industry and services
#
#
# 5.3
# Science and technology
#
#
# 6
# Infrastructure
#
#
# 6.1
# Transportation
#
#
# 6.2
# Energy
#
#
# 7
# Demographics
#
#
# 7.1
# Languages
#
#
# 7.2
# Religion
#
#
# 7.3
# Education
#
#
# 7.4
# Health
#
#
# 8
# Culture
#
#
# 8.1
# Art and architecture
#
#
# 8.2
# Literature and philosophy
#
#
# 8.3
# Performing arts
#
#
# 8.4
# Media
#
#
# 8.5
# Holidays
#
#
# 8.6
# Cuisine
#
#
# 8.7
# Sports
#
#
# 9
# See also
#
#
# 10
# Notes
#
#
# 11
# References
#
#
# 12
# External links
